# %%
from datetime import *
import pandas as pd
import glob
import warnings
import h5py

# %%
warnings.filterwarnings('ignore')

# %%
start_time = "2018-09-09 00:00:00"
end_time = "2018-08-08 00:00:00"

# %%
format1_path = "./data_format1_20180901_20180909.h5"
format2_path = "./data_format2_20180901_20180909.h5"

# %%
h5data = pd.HDFStore(format1_path)

# %%
h5data.keys()
# Out:
# ['/BCH-USD', '/BTC-USD', '/ETH-USD', '/LTC-USD']

# %%
h5data['BCH-USD']
# Out:
#                       close    high     low    open     volume
# time
# 2018-09-01 00:00:00  541.74  542.00  541.72  542.00   0.544086
# 2018-09-01 00:01:00  541.74  541.74  541.74  541.74   0.000000
# 2018-09-01 00:02:00  541.74  541.74  541.49  541.73  25.090644
# 2018-09-01 00:03:00  541.74  541.74  541.73  541.74   0.574198
# 2018-09-01 00:04:00  542.00  542.00  541.74  541.74  19.124730
# 2018-09-01 00:05:00  541.99  541.99  541.99  541.99   0.058891
# 2018-09-01 00:06:00  543.90  543.91  542.00  542.00   3.887689
# 2018-09-01 00:07:00  543.57  543.97  543.38  543.97   4.272407
# 2018-09-01 00:08:00  543.57  543.99  543.57  543.97   4.887275
# 2018-09-01 00:09:00  543.57  543.99  543.57  543.99   5.526671
# 2018-09-01 00:10:00  543.68  543.68  543.67  543.67   4.194497
# 2018-09-01 00:11:00  543.39  543.68  543.38  543.68   4.658360
# 2018-09-01 00:12:00  543.37  543.39  543.37  543.37   0.422856
# 2018-09-01 00:13:00  543.24  543.37  543.24  543.37  20.000000
# ...
