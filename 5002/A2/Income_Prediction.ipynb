# %% [markdown]
# # MSBD 5002 Assignment 2 - Income Prediction

# %%
import os
import time
import numpy as np
import pandas as pd
import sklearn as skl
import matplotlib as mpl
import seaborn as sns
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Feature Engineering

# %%
data_folder = './data/'
training_features = 'trainFeatures.csv'
training_lables = 'trainLabels.csv'
testing_data = 'testFeatures.csv'

train_x = pd.read_csv(os.path.join(data_folder, training_features))
train_y = pd.read_csv(os.path.join(data_folder, training_lables), header = None, names=['over50k'])
test_x = pd.read_csv(os.path.join(data_folder, testing_data))

# %%
train_x.head(20)
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 0    24            Private  258298      Assoc-voc             11
# 1    28            Private  208249   Some-college             10
# 2    49            Private  143459            9th              5
# 3    24            Private  228772        5th-6th              3
# 4    20          State-gov   41103   Some-college             10
# 5    24            Private   89154            9th              5
# 6    57            Private  157749   Some-college             10
# 7    30            Private  202046        HS-grad              9
# 8    40            Private  163434   Some-college             10
# 9    20            Private  180339        HS-grad              9
# 10   53                  ?  237868        HS-grad              9
# 11   51            Private  120173      Assoc-voc             11
# 12   22            Private  264738        HS-grad              9
# 13   18                  ?  269373           12th              8
# 14   27          State-gov   31935   Some-college             10
# 15   56   Self-emp-not-inc  177368   Some-college             10
# 16   50            Private  301583        HS-grad              9
# 17   27            Private  122913        7th-8th              4
# 18   46            Private  241935           11th              7
# 19   37          Local-gov  174924   Some-college             10
#
#          Marital-status          occupation     relationship    race      sex  \
# 0         Never-married        Tech-support    Not-in-family   White     Male
# 1              Divorced        Tech-support    Not-in-family   White     Male
# 2             Separated   Handlers-cleaners        Own-child   White     Male
# 3         Never-married   Machine-op-inspct   Other-relative   White   Female
# 4         Never-married       Other-service        Own-child   White   Female
# 5         Never-married       Other-service    Not-in-family   White     Male
# 6    Married-civ-spouse        Craft-repair          Husband   White     Male
# 7         Never-married        Adm-clerical    Not-in-family   White     Male
# 8    Married-civ-spouse   Handlers-cleaners          Husband   White     Male
# 9         Never-married       Other-service   Other-relative   White   Female
# 10   Married-civ-spouse                   ?          Husband   White     Male
# 11   Married-civ-spouse        Craft-repair          Husband   White     Male
# 12        Never-married     Exec-managerial   Other-relative   White   Female
# 13        Never-married                   ?        Own-child   White   Female
# 14        Never-married        Tech-support        Own-child   White   Female
# 15   Married-civ-spouse     Protective-serv          Husband   White     Male
# 16        Never-married   Machine-op-inspct    Not-in-family   White     Male
# 17   Married-civ-spouse    Transport-moving          Husband   White     Male
# 18   Married-civ-spouse       Other-service          Husband   Black     Male
# 19             Divorced     Protective-serv        Unmarried   White     Male
#
#     capital-gain  capital-loss  hours-per-week  native-country
# 0              0             0              45   United-States
# 1              0             0              24   United-States
# 2              0             0              38   United-States
# 3              0             0              40          Mexico
# 4              0             0              20   United-States
# 5              0             0              40     El-Salvador
# 6              0             0              40   United-States
# 7              0             0              20   United-States
# 8              0             0              40   United-States
# 9              0             0              35   United-States
# 10             0             0              35   United-States
# 11          3103             0              50   United-States
# 12             0             0              42         Germany
# 13             0             0              20   United-States
# 14             0             0              80   United-States
# 15             0             0              50   United-States
# 16             0             0              40   United-States
# 17             0             0              40   United-States
# 18          7688             0              40   United-States
# 19             0             0              48         Germany

# %%
test_x.head(20)
# Out:
#     age      workclass  fnlwgt      education  education-num  \
# 0    51        Private  150999        HS-grad              9
# 1    41        Private  433989      Assoc-voc             11
# 2    41      Local-gov  183009        HS-grad              9
# 3    59        Private  200316        HS-grad              9
# 4    53        Private   77462   Some-college             10
# 5    52        Private   46788      Bachelors             13
# 6    42              ?  240027        HS-grad              9
# 7    47        Private  135246           11th              7
# 8    37        Private  105044      Bachelors             13
# 9    25        Private  218136   Some-college             10
# 10   59        Private   43221   Some-college             10
# 11   90        Private   87285        HS-grad              9
# 12   29        Private  319998            9th              5
# 13   26        Private  110103        HS-grad              9
# 14   31   Self-emp-inc  243165        HS-grad              9
# 15   50        Private  248619        HS-grad              9
# 16   66   Self-emp-inc  185369           10th              6
# 17   38        Private  149347        HS-grad              9
# 18   36        Private  140854        7th-8th              4
# 19   61      State-gov  140851      Bachelors             13
#
#          Marital-status          occupation    relationship    race      sex  \
# 0    Married-civ-spouse   Machine-op-inspct         Husband   White     Male
# 1    Married-civ-spouse               Sales         Husband   White     Male
# 2    Married-civ-spouse    Transport-moving         Husband   Black     Male
# 3    Married-civ-spouse        Craft-repair         Husband   White     Male
# 4             Separated      Prof-specialty   Not-in-family   White     Male
# 5              Divorced        Craft-repair       Unmarried   White     Male
# 6              Divorced                   ?   Not-in-family   Black   Female
# 7         Never-married        Craft-repair       Unmarried   White     Male
# 8    Married-civ-spouse      Prof-specialty         Husband   White     Male
# 9         Never-married   Handlers-cleaners   Not-in-family   Black     Male
# 10   Married-civ-spouse        Craft-repair         Husband   White     Male
# 11        Never-married       Other-service       Own-child   White   Female
# 12   Married-civ-spouse        Craft-repair         Husband   White     Male
# 13        Never-married       Other-service   Not-in-family   White   Female
# 14   Married-civ-spouse               Sales         Husband   White     Male
# 15   Married-civ-spouse        Craft-repair         Husband   White     Male
# 16   Married-civ-spouse               Sales         Husband   White     Male
# 17   Married-civ-spouse        Craft-repair         Husband   White     Male
# 18   Married-civ-spouse        Adm-clerical         Husband   White     Male
# 19   Married-civ-spouse      Prof-specialty         Husband   White     Male
#
#     capital-gain  capital-loss  hours-per-week               native-country
# 0              0             0              40                United-States
# 1           4386             0              60                United-States
# 2              0             0              40                United-States
# 3              0             0              40                United-States
# 4              0             0              60                United-States
# 5              0             0              25                United-States
# 6              0             0              40                United-States
# 7              0             0              40                United-States
# 8              0             0              40                United-States
# 9              0             0              40   Outlying-US(Guam-USVI-etc)
# 10             0             0              43                United-States
# 11             0             0              24                United-States
# 12             0             0              40                United-States
# 13             0          1762              40                United-States
# 14             0             0              50                United-States
# 15             0             0              40                United-States
# 16             0             0              30                United-States
# 17             0             0              40                United-States
# 18             0             0              45                     Portugal
# 19             0             0              40                United-States

# %%
# data_labels.head(30)
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
# Out:
# (34189, 14)
# (34189, 1)
# (14653, 14)

# %% [markdown]
# ### Handle missing value

# %%
train_x.drop(columns=['education'], inplace=True)
train_x.rename(columns={'education-num': 'education'}, inplace=True)
test_x.drop(columns=['education'], inplace=True)
test_x.rename(columns={'education-num': 'education'}, inplace=True)
print('')

# %%
train_x.head(20)
# Out:
#     age          workclass  fnlwgt  education       Marital-status  \
# 0    24            Private  258298         11        Never-married
# 1    28            Private  208249         10             Divorced
# 2    49            Private  143459          5            Separated
# 3    24            Private  228772          3        Never-married
# 4    20          State-gov   41103         10        Never-married
# 5    24            Private   89154          5        Never-married
# 6    57            Private  157749         10   Married-civ-spouse
# 7    30            Private  202046          9        Never-married
# 8    40            Private  163434         10   Married-civ-spouse
# 9    20            Private  180339          9        Never-married
# 10   53                  ?  237868          9   Married-civ-spouse
# 11   51            Private  120173         11   Married-civ-spouse
# 12   22            Private  264738          9        Never-married
# 13   18                  ?  269373          8        Never-married
# 14   27          State-gov   31935         10        Never-married
# 15   56   Self-emp-not-inc  177368         10   Married-civ-spouse
# 16   50            Private  301583          9        Never-married
# 17   27            Private  122913          4   Married-civ-spouse
# 18   46            Private  241935          7   Married-civ-spouse
# 19   37          Local-gov  174924         10             Divorced
#
#             occupation     relationship    race      sex  capital-gain  \
# 0         Tech-support    Not-in-family   White     Male             0
# 1         Tech-support    Not-in-family   White     Male             0
# 2    Handlers-cleaners        Own-child   White     Male             0
# 3    Machine-op-inspct   Other-relative   White   Female             0
# 4        Other-service        Own-child   White   Female             0
# 5        Other-service    Not-in-family   White     Male             0
# 6         Craft-repair          Husband   White     Male             0
# 7         Adm-clerical    Not-in-family   White     Male             0
# 8    Handlers-cleaners          Husband   White     Male             0
# 9        Other-service   Other-relative   White   Female             0
# 10                   ?          Husband   White     Male             0
# 11        Craft-repair          Husband   White     Male          3103
# 12     Exec-managerial   Other-relative   White   Female             0
# 13                   ?        Own-child   White   Female             0
# 14        Tech-support        Own-child   White   Female             0
# 15     Protective-serv          Husband   White     Male             0
# 16   Machine-op-inspct    Not-in-family   White     Male             0
# 17    Transport-moving          Husband   White     Male             0
# 18       Other-service          Husband   Black     Male          7688
# 19     Protective-serv        Unmarried   White     Male             0
#
#     capital-loss  hours-per-week  native-country
# 0              0              45   United-States
# 1              0              24   United-States
# 2              0              38   United-States
# 3              0              40          Mexico
# 4              0              20   United-States
# 5              0              40     El-Salvador
# 6              0              40   United-States
# 7              0              20   United-States
# 8              0              40   United-States
# 9              0              35   United-States
# 10             0              35   United-States
# 11             0              50   United-States
# 12             0              42         Germany
# 13             0              20   United-States
# 14             0              80   United-States
# 15             0              50   United-States
# 16             0              40   United-States
# 17             0              40   United-States
# 18             0              40   United-States
# 19             0              48         Germany

# %%
nominal_columns = ['workclass', 'Marital-status', 'occupation', 'relationship', 'race', 'sex', 
       'native-country']

def missing_value_handler(column, replaced_value):
    for i in range(len(column)):
        if column[i] == ' ?' or column[i] == '?':
            column[i] = replaced_value

            
for cln in nominal_columns:
    missing_value_handler(train_x[cln], '') # empty string filling as mode

for cln in nominal_columns:
    missing_value_handler(test_x[cln], '') # empty string filling as mode

# %%
# Out:
#   File "<ipython-input-10-7468e9a122cf>", line 1
#     train_x[]
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Nominal value transform

# %%
# quantize_column = nominal_columns - ['workclass', '']

def quantize(column_name, dataset):
    column_maping = {label: idx for idx, label in enumerate(set(dataset[column_name]))}
    dataset[column_name] = dataset[column_name].map(column_maping)

for cln_name in nominal_columns:
    quantize(cln_name, train_x)
    quantize(cln_name, test_x)

# %%
# one hot encode

# from sklearn.preprocessing import OneHotEncoder

# def onehotize(column):
#     oh_encoder = OneHotEncoder()
#     oh_encoder.fit(column)
#     oh_result = oh_encoder.trasf
#     return oh_result

# %%
# oh_encoder.fit(train_x['sex'].reshape(1, -1))
# oh_encoder.transform(train_x['sex'])

# %%
# %matplotlib inline
feature_corr = train_x.corr()

fig = plt.figure(figsize=(13, 13))
sns.heatmap(feature_corr, annot=True, linewidths=.5, fmt= '.4f', cmap=plt.cm.Reds)
plt.title("Feature Correlations",fontsize=12)
fig.show()

# %%
# col = train_x['workclass']
# col[10] = ' 111'
# train_x['workclass'][10]
# range(len(col))
# train_x['workclass'].value_counts().index[0]
# train_x['workclass'].head(50)

# %% [markdown]
# ### Model Training

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
# import xgboost as xgb
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x_train, x_validate, y_train, y_validate = train_test_split(train_x, train_y, test_size=0.3)

# %%
# Adaboost
adb_clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1), n_estimators=1000)

score = cross_val_score(adb_clf, train_x, train_y, cv=5)

# %%
np.mean(score)
# Out:
# 0.8717716670912037

# %%
adb_clf = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1), n_estimators=1000)
adb_clf.fit(train_x, train_y)
result = adb_clf.predict(test_x)

# %%
result = pd.Series(result)
result
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
# 5        0
# 6        0
# 7        0
# 8        1
# 9        0
# 10       1
# 11       0
# 12       0
# 13       0
# 14       1
# 15       1
# 16       0
# 17       1
# 18       0
# 19       1
# 20       0
# 21       0
# 22       0
# 23       0
# 24       1
# 25       0
# 26       0
# 27       0
# 28       0
# 29       0
#         ..
# 14623    1
# 14624    1
# 14625    0
# 14626    0
# 14627    0
# 14628    0
# 14629    1
# 14630    0
# 14631    0
# 14632    1
# 14633    1
# 14634    0
# 14635    0
# 14636    0
# 14637    0
# 14638    0
# 14639    0
# 14640    1
# 14641    0
# 14642    0
# 14643    1
# 14644    0
# 14645    0
# 14646    0
# 14647    0
# 14648    1
# 14649    0
# 14650    1
# 14651    0
# 14652    0
# Length: 14653, dtype: int64

# %%
result.to_csv('./A2_itsc_stuid_prediction.csv', header=False, index=False)
