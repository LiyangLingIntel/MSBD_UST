# %%
import numpy as np
import pandas as pd

from string import punctuation

from gensim.models import Word2Vec
from gensim.models.doc2vec import TaggedDocument
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.preprocessing import scale
from tqdm import tqdm

from sklearn.cluster import KMeans

# %%
tokenizer = TweetTokenizer()
stop_words = set(stopwords.words('english'))
tqdm.pandas(desc="progress-bar")

# %%
data_root = './'

# %% [markdown]
# ### Data prepare & process

# %%
with open('./text.txt', 'r') as f:
    content = f.readlines()
content = [sent[:-1] for sent in content if sent != '\n']

df = pd.DataFrame({'Contents': content})

# %%
df.head()
# Out:
#                                             Contents
# 0  The work of Dr. He Jiankui presented at GeneEd...
# 1  The Chinese scientist He Jiankui claims he hel...
# 2  This is the future. Hard to accept but this wi...
# 3  They can’t represent Chinese scientist. The wh...
# 4  He stopped twins being born HIV positive. I do...

# %%
def tokenize(sentence):
    tokens = [x.lower() for x in tokenizer.tokenize(sentence)]
#     tokens = [x for x in tokens if x not in stop_words]
    tokens = [x for x in tokens if x not in punctuation]  # punctuation may be useful, to simplify this problem, I don't use it here
    if tokens:
        return tokens
    else:
        return np.NaN

# %%
df['tokens'] = df['Contents'].map(tokenize)

# %%
def labelize_tweets(tweets, label_type):
    labelized = []
    for i,v in tqdm(enumerate(tweets)):
        label = f'{label_type}_{i}'
        labelized.append(TaggedDocument(v, [label]))
    return labelized

# %%
train_x = np.array(df.tokens)

# %%
w2v = Word2Vec(size=200, window=10, min_count=2, workers=10)
w2v.build_vocab([x for x in train_x])
x = [x for x in train_x]
w2v.train(x, total_examples=len(x), epochs=10)
# Out:
# (13651, 29150)

# %%
len(w2v.wv.vocab.keys())
# Out:
# 341

# %%
vectorizer = TfidfVectorizer(analyzer=lambda x: x, min_df=10)
matrix = vectorizer.fit_transform([x for x in train_x])
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
len(tfidf)
# Out:
# vocab size : 40

# %%
def buildWordVector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count = 0.
    for word in tokens:
        try:
            vec += w2v[word].reshape((1, size)) * tfidf.get(word, 1)
            count += 1.
        except KeyError: # handling the case where the token is not
                         # in the corpus. useful for testing.
            continue
    if count != 0:
        vec /= count
    return vec

# %%
train_vecs = np.concatenate([buildWordVector(z, 200) for z in train_x])
train_vecs = scale(train_vecs)
# Out:
# /Users/leonling/workspace/pyenv/py36/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
clt = KMeans(n_clusters=2, random_state=0)
labels = clt.fit_predict(train_vecs)

# %%
df['Result'] = labels
df = df.reset_index().rename(columns={'index':'ID'})

df[['ID', 'Contents', 'Result']].to_csv('./Q5_output.csv', index=False)

# %%
df
# Out:
#     ID  ID                                           Contents  \
# 0    0   0  The work of Dr. He Jiankui presented at GeneEd...
# 1    1   1  The Chinese scientist He Jiankui claims he hel...
# 2    2   2  This is the future. Hard to accept but this wi...
# 3    3   3  They can’t represent Chinese scientist. The wh...
# 4    4   4  He stopped twins being born HIV positive. I do...
# 5    5   5  If true this is wrong and don’t mess with the ...
# 6    6   6  Sure! If the US does it!, nobody would have an...
# 7    7   7  It is true. Cost per genome and genome sequenc...
# 8    8   8         This sounds good.let's hope this is true .
# 9    9   9  Here's the rub. Normally ethical oversight com...
# 10  10  10  China May just be doing their best technologic...
# 11  11  11  It’s against human morality. If it’s allowed t...
# 12  12  12  This is really shady maybe his claims weren't ...
# 13  13  13  Harvard aims to use CRISPR gene editing to eli...
# 14  14  14  The behavior shouldn't be allowed, unless We c...
# 15  15  15  Damn! I wish he would have edited my genes so ...
# 16  16  16  Dr. He Jiankui, a modern day Edward Jenner, de...
# 17  17  17  So either a Noble prize or gallow's both are p...
# 18  18  18  Such policies are necessary in order to ensure...
# 19  19  19  A smart take on human genetic engineering. “We...
# 20  20  20  Honored to be playing at the 2019 Congrés Mond...
# 21  21  21  N5 Biologists producing some excellent diagram...
# 22  22  22  A genetically modified organism is any organis...
# 23  23  23  Important discussion! The compulsion by some s...
# 24  24  24  The writing is a bit dated, but you should rea...
# 25  25  25  After Second Phase III Failure, AstraZeneca Re...
# 26  26  26  Very happy to share our first paper on genome ...
# 27  27  27  Thank you. The potential problem/issue I see w...
# 28  28  28  Thank you for speaking up, Doctor. It is frust...
# 29  29  29  B cells inhibit bone formation in rheumatoidar...
# ..  ..  ..                                                ...
# 70  70  70  Someone should make a Rice gene editing startu...
# 71  71  71  We are upset about the ethicacy of editing Gen...
# 72  72  72  Even though the world at large is going to ban...
# 73  73  73  The whole recent gene editing stuff triggers m...
# 74  74  74  People who are against Gene editing to remove ...
# 75  75  75  If you're against gene editing of humans, you'...
# 76  76  76  Mostly I just think people with a moral panic ...
# 77  77  77  Also hooves are 100% the better choice as a fi...
# 78  78  78  when working out the art of science. These fam...
# 79  79  79  I don't condone what He did, but since it is a...
# 80  80  80  so whether we acknowledge it as a good or bad ...
# 81  81  81  Scientific American reports there has been a b...
# 82  82  82  On the topic of gene editing, does this open u...
# 83  83  83  The ethics of gene editing is such an interest...
# 84  84  84  Phew, reading up on that whole gene editing cr...
# 85  85  85  We are passionate about our research and the t...
# 86  86  86  Our present technological paradox: even as AI ...
# 87  87  87  You may have heard about the presentation at t...
# 88  88  88  "They have been gene editing humans including ...
# 89  89  89  You mean the “scientist” who ran with gene edi...
# 90  90  90  People can scream about gene editing all they ...
# 91  91  91  If gene editing is done responsably and with t...
# 92  92  92  Gene editing babies will be okay so long as th...
# 93  93  93  "If you want to talk about science, if you wan...
# 94  94  94  We are but plus one new trend in the world of ...
# 95  95  95  I keep hearing people everywhere talk about th...
# 96  96  96  My genetics professor was fangirling over CRIS...
# 97  97  97  The need for responsible innovation is as appl...
# 98  98  98  Spoiler alert: we did it in human embryos. But...
# 99  99  99  Weeding out ignorance, poverty, mental illness...
#
#                                                tokens  Result
# 0   [The, work, of, Dr, He, Jiankui, presented, at...       0
# 1   [The, Chinese, scientist, He, Jiankui, claims,...       1
# 2   [This, is, the, future, Hard, to, accept, but,...       0
# 3   [They, can, ’, t, represent, Chinese, scientis...       1
# 4   [He, stopped, twins, being, born, HIV, positiv...       1
# 5   [If, true, this, is, wrong, and, don, ’, t, me...       0
# 6   [Sure, If, the, US, does, it, nobody, would, h...       0
# 7   [It, is, true, Cost, per, genome, and, genome,...       0
# 8   [This, sounds, good.let, s, hope, this, is, true]       0
# 9   [Here's, the, rub, Normally, ethical, oversigh...       1
# 10  [China, May, just, be, doing, their, best, tec...       1
# 11  [It, ’, s, against, human, morality, If, it, ’...       0
# 12  [This, is, really, shady, maybe, his, claims, ...       0
# 13  [Harvard, aims, to, use, CRISPR, gene, editing...       0
# 14  [The, behavior, shouldn't, be, allowed, unless...       0
# 15  [Damn, I, wish, he, would, have, edited, my, g...       0
# 16  [Dr, He, Jiankui, a, modern, day, Edward, Jenn...       1
# 17  [So, either, a, Noble, prize, or, gallow's, bo...       1
# 18  [Such, policies, are, necessary, in, order, to...       0
# 19  [A, smart, take, on, human, genetic, engineeri...       0
# 20  [Honored, to, be, playing, at, the, 2019, Cong...       0
# 21  [N5, Biologists, producing, some, excellent, d...       0
# 22  [A, genetically, modified, organism, is, any, ...       1
# 23  [Important, discussion, The, compulsion, by, s...       1
# 24  [The, writing, is, a, bit, dated, but, you, sh...       0
# 25  [After, Second, Phase, III, Failure, AstraZene...       1
# 26  [Very, happy, to, share, our, first, paper, on...       1
# 27  [Thank, you, The, potential, problem, issue, I...       1
# 28  [Thank, you, for, speaking, up, Doctor, It, is...       1
# 29  [B, cells, inhibit, bone, formation, in, rheum...       1
# ..                                                ...     ...
# 70  [Someone, should, make, a, Rice, gene, editing...       0
# 71  [We, are, upset, about, the, ethicacy, of, edi...       0
# 72  [Even, though, the, world, at, large, is, goin...       1
# 73  [The, whole, recent, gene, editing, stuff, tri...       1
# 74  [People, who, are, against, Gene, editing, to,...       0
# 75  [If, you're, against, gene, editing, of, human...       0
# 76  [Mostly, I, just, think, people, with, a, mora...       0
# 77  [Also, hooves, are, 100, the, better, choice, ...       0
# 78  [when, working, out, the, art, of, science, Th...       0
# 79  [I, don't, condone, what, He, did, but, since,...       0
# 80  [so, whether, we, acknowledge, it, as, a, good...       0
# 81  [Scientific, American, reports, there, has, be...       0
# 82  [On, the, topic, of, gene, editing, does, this...       0
# 83  [The, ethics, of, gene, editing, is, such, an,...       0
# 84  [Phew, reading, up, on, that, whole, gene, edi...       0
# 85  [We, are, passionate, about, our, research, an...       0
# 86  [Our, present, technological, paradox, even, a...       0
# 87  [You, may, have, heard, about, the, presentati...       1
# 88  [They, have, been, gene, editing, humans, incl...       0
# 89  [You, mean, the, “, scientist, ”, who, ran, wi...       0
# 90  [People, can, scream, about, gene, editing, al...       1
# 91  [If, gene, editing, is, done, responsably, and...       0
# 92  [Gene, editing, babies, will, be, okay, so, lo...       0
# 93  [If, you, want, to, talk, about, science, if, ...       0
# 94  [We, are, but, plus, one, new, trend, in, the,...       0
# 95  [I, keep, hearing, people, everywhere, talk, a...       1
# 96  [My, genetics, professor, was, fangirling, ove...       1
# 97  [The, need, for, responsible, innovation, is, ...       0
# 98  [Spoiler, alert, we, did, it, in, human, embry...       0
# 99  [Weeding, out, ignorance, poverty, mental, ill...       1
#
# [100 rows x 5 columns]
